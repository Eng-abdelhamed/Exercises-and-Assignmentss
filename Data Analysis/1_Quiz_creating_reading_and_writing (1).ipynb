# %% [markdown]
# <a href="https://colab.research.google.com/github/Eng-abdelhamed/Exercises-and-Assignmentss/blob/main/1_Quiz_creating_reading_and_writing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# The first step in most data analytics projects is reading the data file. In this exercise, you'll create Series and DataFrame objects, both by hand and by reading data files.
#
# Run the code cell below to load libraries you will need (including code to check your answers).

# %%
import pandas as pd
#pd.set_option('max_rows', 5)

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
#
# In the cell below, create a DataFrame `fruits` that looks like this:
#
# ![](https://i.imgur.com/Ax3pp2A.png)

# %%
# Your code goes here. Create a dataframe matching the above diagram and assign it to the variable fruits.
fruits = pd.DataFrame({'Apples':[30] ,'Bananas':[21]})
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %% [markdown]
# ## 2.
#
# Create a dataframe `fruit_sales` that matches the diagram below:
#
# ![](https://i.imgur.com/CHPn7ZF.png)

# %%
# Your code goes here. Create a dataframe matching the above diagram and assign it to the variable fruit_sales.
fruit_sales = pd.DataFrame({'Apples':[35,41] ,'Bananas':[21,34]}
                           ,index=['2017 Sales','2018 Sales'])
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %% [markdown]
# ## 3.
#
# Create a variable `ingredients` with a Series that looks like:
#
# ```
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object
# ```

# %%
ingredients = pd.Series(['4 cups','1 cup','2 large','1 can'],
                        index=['Flour','Milk','Eggs','Spam'])
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# dtype: object

# %% [markdown]
# ## 4.
#
# Read the following csv dataset of wine reviews into a DataFrame called `reviews`:
#
# ![](https://i.imgur.com/74RCZtU.png)
#
# The filepath to the csv file is `../input/wine-reviews/winemag-data_first150k.csv`. The first few lines look like:
#
# ```
# ,country,description,designation,points,price,province,region_1,region_2,variety,winery
# 0,US,"This tremendous 100% varietal wine[...]",Martha's Vineyard,96,235.0,California,Napa Valley,Napa,Cabernet Sauvignon,Heitz
# 1,Spain,"Ripe aromas of fig, blackberry and[...]",Carodorum Selección Especial Reserva,96,110.0,Northern Spain,Toro,,Tinta de Toro,Bodega Carmen Rodríguez
# ```

# %%
reviews = pd.read_csv('winemag-data_first150k.csv',chunksize=10000,index_col = 0)
next(reviews)
# Out:
#      country                                        description  \
# 0         US  This tremendous 100% varietal wine hails from ...
# 1      Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2         US  Mac Watson honors the memory of a wine once ma...
# 3         US  This spent 20 months in 30% new French oak, an...
# 4     France  This is the top wine from La Bégude, named aft...
# ...      ...                                                ...
# 9995   Chile  Pickled, briny aromas lead to a palate defined...
# 9996   Chile  This is overtly rustic, roasted, leathery and ...
# 9997   Chile  Leesy vanilla aromas are bland and don't amoun...
# 9998   Chile  Powdery bath-soap aromas are odd on the nose. ...
# 9999   Chile  Aromas of spiced tomato, clove and rubber glov...
#
#                                             designation  points  price  \
# 0                                     Martha's Vineyard      96  235.0
# 1                  Carodorum Selección Especial Reserva      96  110.0
# 2                         Special Selected Late Harvest      96   90.0
# 3                                               Reserve      96   65.0
# 4                                            La Brûlade      95   66.0
# ...                                                 ...     ...    ...
# 9995  Fina Reserva Ensamblaje Sauvignon Blanc-Chardo...      81   19.0
# 9996                                            Reserva      81   10.0
# 9997                                                NaN      81   13.0
# 9998                                       Gran Reserva      81   11.0
# 9999                                               Bold      81   10.0
#
#               province           region_1           region_2  \
# 0           California        Napa Valley               Napa
# 1       Northern Spain               Toro                NaN
# 2           California     Knights Valley             Sonoma
# 3               Oregon  Willamette Valley  Willamette Valley
# 4             Provence             Bandol                NaN
# ...                ...                ...                ...
# 9995  Colchagua Valley                NaN                NaN
# 9996      Maule Valley                NaN                NaN
# 9997    Central Valley                NaN                NaN
# 9998      Leyda Valley                NaN                NaN
# 9999    Central Valley                NaN                NaN
#
#                  variety                   winery
# 0     Cabernet Sauvignon                    Heitz
# 1          Tinta de Toro  Bodega Carmen Rodríguez
# 2        Sauvignon Blanc                 Macauley
# 3             Pinot Noir                    Ponzi
# 4     Provence red blend     Domaine de la Bégude
# ...                  ...                      ...
# 9995         White Blend                  Estampa
# 9996  Cabernet Sauvignon    Viña Casas Patronales
# 9997     Sauvignon Blanc                 Kon Tiki
# 9998     Sauvignon Blanc                Autoritas
# 9999  Cabernet Sauvignon             Terra Andina
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## 5.
#
# Run the cell below to create and display a DataFrame called `animals`:

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %% [markdown]
# In the cell below, write code to save this DataFrame to disk as a csv file with the name `cows_and_goats.csv`.

# %%
# Your code goes here
animals.to_csv('cows_and_goats.csv')

# %% [markdown]
# # Keep going
